# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Exercise 1 Iris Datasets
# Gunakan dataset iris pada link berikut https://raw.githubusercontent.com/elflin/datasets/main/Iris.csv </br>
# untuk melakukan klasifikasi menggunakna K-NN dan Naive Bayes

# %% [markdown]
# ## Load Dataset

# %%
# Load data dari link github berikut
# Munculkan head() dari data
url = "https://raw.githubusercontent.com/elflin/datasets/main/Iris.csv"

# %%
# Munculkan informasi dari column pada data

# %%
# Munculkan deskripsi dari masing-masing column pada data

# %%
# Show unique class

# %%
color_list = ['red' if i=='Iris-setosa' else 
              'blue' if i=='Iris-versicolor' else 
              'green' 
              for i in data.loc[:,'Species']
              ]
pd.plotting.scatter_matrix(
    data.loc[:, data.columns != 'Species'], 
    c=color_list,
    figsize= [15,15],
    diagonal='hist',
    )
plt.show()

# %% [markdown]
# ## Pre-procesing Data

# %%
# Pisahkan dataset menjadi x dan y menggunakna loc

# %%
# Normalisasi data

# %%
# Setelah dataset dibagi menjadi x = atribut dan y = class kemudian dipisahkan menjadi data training dan testing menggunakan train_test_split()

# %% [markdown]
# ## K-Nearest Neigbour

# %%
from sklearn.neighbors import KNeighborsClassifier
# Buat model menggunakan KNeighborsClassifier dengan K = 4


# Lakukan training dengan dataset train

# %%
# Lakukan prediksi menggunakan x_test lalu print class hasil prediksi

# %%
# Print akurasi dari data testing menggunakan score

# %%
# Model complexity


# Plot
plt.figure(figsize=[13,8])
plt.plot(neig, test_accuracy, label = 'Testing Accuracy')
plt.plot(neig, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(neig)
plt.savefig('graph.png')
plt.show()
print("Best accuracy is {} with K = {}".format(np.max(test_accuracy),
1+test_accuracy.index(np.max(test_accuracy))))

# %%
# Pilih K terbaik dari data percobaan di atas

# %%
from sklearn.metrics import confusion_matrix
# Matriks confusion array using sklearn

# %%
import seaborn as sns
# show heatmap

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB


# Lakukan training dengan dataset train

# %%
# Lakukan prediksi menggunakan x_test lalu print class hasil prediksi

# %%
# Print akurasi

# %%
# Matriks confusion array using sklearn

# %%
import seaborn as sns
# show heatmap

# %% [markdown]
# # Exercise 2 Orthopedic Datasets
# Gunakan dataset iris pada link berikut https://raw.githubusercontent.com/elflin/datasets/main/orthopedic_3class.csv </br>
# untuk melakukan klasifikasi menggunakna K-NN dan Naive Bayes

# %% [markdown]
# ## Load Dataset

# %%
# Load data dari link github berikut
# Munculkan head() dari data

# %%
# Munculkan informasi dari column pada data

# %%
# Munculkan deskripsi dari masing-masing column pada data

# %%
# Show unique class

# %%
color_list = ['red' if i=='Hernia' else 
              'blue' if i=='Spondylolisthesis' else 
              'green' 
              for i in data.loc[:,'class_status']
              ]

# %% [markdown]
# ## Pre-procesing Data

# %%
# Pisahkan dataset menjadi x dan y menggunakna loc

# %%
# Normalisasi data

# %%
# Setelah dataset dibagi menjadi x = atribut dan y = class kemudian dipisahkan menjadi data training dan testing menggunakan train_test_split()
# Split test size 20% dan random state 20

# %% [markdown]
# ## K-Nearest Neigbour

# %%
from sklearn.neighbors import KNeighborsClassifier
# Buat model menggunakan KNeighborsClassifier dengan K = 4


# Lakukan training dengan dataset train

# %%
# Lakukan prediksi menggunakan x_test lalu print class hasil prediksi

# %%
# Print akurasi dari data testing menggunakan score

# %%
# Model complexity


# Plot
plt.figure(figsize=[13,8])
plt.plot(neig, test_accuracy, label = 'Testing Accuracy')
plt.plot(neig, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(neig)
plt.savefig('graph.png')
plt.show()
print("Best accuracy is {} with K = {}".format(np.max(test_accuracy),
1+test_accuracy.index(np.max(test_accuracy))))

# %%
# Pilih K terbaik dari data percobaan di atas

# %%
from sklearn.metrics import confusion_matrix
# Matriks confusion array using sklearn

# %%
import seaborn as sns
# show heatmap

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB


# Lakukan training dengan dataset train

# %%
# Lakukan prediksi menggunakan x_test lalu print class hasil prediksi

# %%
# Print akurasi

# %%
# Matriks confusion array using sklearn

# %%
import seaborn as sns
# show heatmap

# %% [markdown]
# # Assignment
# Gunakan dataset iris pada link berikut https://raw.githubusercontent.com/twiradinata/datasets/main/fish-weight.csv </br>
# untuk melakukan klasifikasi menggunakna K-NN dan Naive Bayes

# %% [markdown]
# ## Load Dataset

# %%
# Load data dari link github berikut
# Munculkan head() dari data

# %%
# Munculkan informasi dari column pada data

# %%
# Munculkan deskripsi dari masing-masing column pada data

# %%
# Show unique class

# %%
color_list = ['red' if i=='Bream' else 
              'blue' if i=='Roach' else
              'yellow' if i=='Whitefish' else
              'black' if i=='Parkki' else 
              'purple' if i=='Perch' else
              'orange' if i=='Pike' else 
              'green' 
              for i in data.loc[:,'Species']
              ]

# Show plot attributes

# %% [markdown]
# ## Pre-procesing Data

# %%
# Pisahkan dataset menjadi x dan y menggunakna loc

# %%
# Normalisasi data

# %%
# Setelah dataset dibagi menjadi x = atribut dan y = class kemudian dipisahkan menjadi data training dan testing menggunakan train_test_split()
# split test size = 0.3 dan random state 20

# %% [markdown]
# ## K-Nearest Neigbour

# %%
from sklearn.neighbors import KNeighborsClassifier
# Buat model menggunakan KNeighborsClassifier dengan K = 4


# Lakukan training dengan dataset train

# %%
# Lakukan prediksi menggunakan x_test lalu print class hasil prediksi

# %%
# Print akurasi dari data testing menggunakan score

# %%
# Model complexity

# Loop over different values of k

# Plot

# %%
# Pilih K terbaik dari data percobaan di atas

# %%
# Matriks confusion array using sklearn

# %%
import seaborn as sns
# show heatmap

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB


# Lakukan training dengan dataset train

# %%
# Lakukan prediksi menggunakan x_test lalu print class hasil prediksi

# %%
# Print akurasi

# %%
# Matriks confusion array using sklearn

# %%
import seaborn as sns
# show heatmap
